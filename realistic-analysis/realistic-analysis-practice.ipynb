# %%
# Load the dataset
import numpy as np
import pandas as pd

df = pd.read_csv("realistic_dataset.csv")

# %%
# Display the first few rows

df.head(10)
# Out:
#   Customer_ID Customer_Name  Age      Gender               Email  \
# 0  CUST000001      yAdkpEBs   56        Male   user1@example.com
# 1  CUST000002      EuVgbDYd   69      Female   user2@example.com
# 2  CUST000003      WjnbWviV   46      Female   user3@example.com
# 3  CUST000004      EIIfByfl   32        Male   user4@example.com
# 4  CUST000005      CYDcXucs   60  Non-Binary   user5@example.com
# 5  CUST000006      jzNhmAZC   25      Female   user6@example.com
# 6  CUST000007      chBXlSKI   38  Non-Binary   user7@example.com
# 7  CUST000008      UHRhYvji   56        Male   user8@example.com
# 8  CUST000009      XVKGkmdF   36  Non-Binary   user9@example.com
# 9  CUST000010      kksvTKPR   40  Non-Binary  user10@example.com
#
#    Phone_Number    Registration_Date   Last_Purchase_Date  Annual_Income  \
# 0    2693320954  2018-10-13 10:57:21  2024-07-10 13:49:07       48187.67
# 1    4507187747  2023-03-31 00:52:29  2020-04-14 15:28:11       38218.52
# ...

# %%
# Check basic info

print("Shape of dataset:\n")
print(df.shape)

print ("            ")

print ("Basic Information reagrding dataset:\n")
df.info()
# Out:
# Shape of dataset:
#
# (80000, 51)
#
# Basic Information reagrding dataset:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 51 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer_ID             80000 non-null  object
#  1   Customer_Name           80000 non-null  object
#  2   Age                     80000 non-null  int64
#  3   Gender                  80000 non-null  object
#  4   Email                   80000 non-null  object
#  5   Phone_Number            80000 non-null  int64
#  6   Registration_Date       80000 non-null  object
#  7   Last_Purchase_Date      80000 non-null  object
#  8   Annual_Income           80000 non-null  float64
#  9   Spending_Score          80000 non-null  int64
#  10  Country                 80000 non-null  object
#  11  City                    80000 non-null  object
#  12  Product_Purchased       80000 non-null  object
# ...

# %%
# Summary statistics for numerical columns

df.describe()
# Out:
#                 Age  Phone_Number  Annual_Income  Spending_Score  \
# count  80000.000000  8.000000e+04   80000.000000    80000.000000
# mean      43.476575  4.988506e+09   50613.900641       50.468337
# std       14.985626  2.887366e+09   18825.027789       28.831280
# min       18.000000  2.378360e+05   20000.000000        1.000000
# 25%       31.000000  2.486465e+09   36607.745000       25.000000
# 50%       43.000000  4.983381e+09   50044.845000       50.000000
# 75%       56.000000  7.487537e+09   63374.832500       75.000000
# max       69.000000  9.999945e+09  143889.450000      100.000000
#
#        Purchase_Amount  Product_Rating  Monthly_Purchases  Loyalty_Points  \
# count     80000.000000    80000.000000       80000.000000    80000.000000
# mean        254.927984        3.006387           9.996163     5028.414675
# std         141.160265        1.153034           5.481868     2888.402484
# min          10.010000        1.000000           1.000000        0.000000
# ...

# %%
# Count of unique values in categorical columns

categorical_columns = df.select_dtypes(include=['object', 'category']).columns

unique_counts = df[categorical_columns].nunique()
print(unique_counts)
# Out:
# Customer_ID              80000
# Customer_Name            80000
# Gender                       3
# Email                    80000
# Registration_Date        79989
# Last_Purchase_Date       79970
# Country                      5
# City                     79999
# Product_Purchased            5
# Membership_Status            3
# Favorite_Category            4
# Customer_Region              4
# Discount_Availability        2
# Payment_Method               4
# Subscription_Status          2
# Referral_Status              2
# Browser_Type                 4
# Device_Type                  3
# Preferred_Brand              3
# dtype: int64

# %%
# Check for missing values

df.isnull().sum()
# Out:
# Customer_ID               0
# Customer_Name             0
# Age                       0
# Gender                    0
# Email                     0
# Phone_Number              0
# Registration_Date         0
# Last_Purchase_Date        0
# Annual_Income             0
# Spending_Score            0
# Country                   0
# City                      0
# Product_Purchased         0
# Purchase_Amount           0
# Product_Rating            0
# Membership_Status         0
# Favorite_Category         0
# Monthly_Purchases         0
# Loyalty_Points            0
# Customer_Region           0
# Discount_Availability     0
# Delivery_Time             0
# Payment_Method            0
# Subscription_Status       0
# Customer_Satisfaction     0
# Total_Purchases           0
# Cart_Abandon_Rate         0
# Referral_Status           0
# Active_Days               0
# Lifetime_Value            0
# Browser_Type              0
# Device_Type               0
# Social_Media_Usage        0
# ...

# %%
# Age distribution

import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df['Age'], kde=False, bins=40, color='indigo')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Number of People')
plt.show()

# %%
# Gender counts

gender_counts = df["Gender"].nunique()
gender_counts
# Out:
# 3

# %%
# Annual Income distribution

sns.histplot(df['Annual_Income'], kde=False, bins=20, color='cyan')
plt.title('Annul  Income Distribution')
plt.xlabel('Annual Income')
plt.ylabel('US Dollars')
plt.show()

# %%
# Spending Score distribution

sns.histplot(df['Spending_Score'], kde=False, bins=30, color='limegreen')
plt.title('Spending Score Distribution')
plt.xlabel('Spending Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Country-wise distribution

sns.histplot(df['Country'], kde=False, bins=20, color='magenta')
plt.title('Country Wise Distribution')
plt.xlabel('Country')
plt.ylabel('Frequency')
plt.show()

# %%
# Correlation matrix

numerical_columns = df.select_dtypes(include=['number']).columns
correlation_matrix = df[numerical_columns].corr()

correlation_matrix
# Out:
#                              Age  Phone_Number  Annual_Income  Spending_Score  \
# Age                     1.000000     -0.000636       0.003638        0.001568
# Phone_Number           -0.000636      1.000000      -0.002978       -0.000490
# Annual_Income           0.003638     -0.002978       1.000000        0.003764
# Spending_Score          0.001568     -0.000490       0.003764        1.000000
# Purchase_Amount         0.001008      0.002128       0.001447       -0.003707
# Product_Rating          0.000445     -0.002598       0.001283        0.002003
# Monthly_Purchases       0.001972      0.010206       0.004784       -0.000685
# Loyalty_Points          0.001847      0.003966      -0.005789       -0.004458
# Delivery_Time           0.003746     -0.003344       0.000684        0.003691
# Customer_Satisfaction  -0.000031      0.000516      -0.008323        0.000355
# Total_Purchases        -0.001552     -0.005050      -0.002245        0.005113
# ...

# %%
# Correlation between income and spending score

print ("Correlation between Annual Income and Spending Score:\n")
df["Annual_Income"].corr(df["Spending_Score"])
# Out:
# Correlation between Annual Income and Spending Score:
# 0.0037641025846801767

# %%
# Average Purchase Amount by Membership Status

average_purchase = df.groupby("Membership_Status")["Purchase_Amount"].mean()
average_purchase
# Out:
# Membership_Status
# Bronze    254.659094
# Gold      254.133110
# Silver    255.993670
# Name: Purchase_Amount, dtype: float64

# %%
# Correlation between Monthly Purchases and Loyalty Points

print ("Correlation between Monthly Purchases and Loyalty Points:\n")
df["Monthly_Purchases"].corr(df["Loyalty_Points"])
# Out:
# Correlation between Monthly Purchases and Loyalty Points:
# -0.0007275826646902263

# %%
# Target variable distribution

sns.histplot(df['Target'], kde=False, bins=20, color='teal')
plt.title('Target Variable Distribution')
plt.xlabel('Target')
plt.ylabel('Frequency')
plt.show()

# %%
# Average income based on target

average_income = df.groupby("Target")["Annual_Income"].mean()
average_income
# Out:
# Target
# 0    50578.372037
# 1    50697.023189
# Name: Annual_Income, dtype: float64

# %%
# Most purchased product

mostpurchased = df["Product_Purchased"].max()
mostpurchased
# Out:
# 'Sports'

# %%
# Average rating by product category

average_rating = df.groupby("Product_Purchased")["Product_Rating"].mean()
average_rating
# Out:
# Product_Purchased
# Books          3.010412
# Clothing       2.996808
# Electronics    3.011343
# Home           3.002964
# Sports         3.010465
# Name: Product_Rating, dtype: float64

# %%
# Average purchase amount based on discount availability

average_amount = df.groupby("Discount_Availability")["Purchase_Amount"].mean()
average_amount
# Out:
# Discount_Availability
# No     255.716160
# Yes    254.138507
# Name: Purchase_Amount, dtype: float64

# %%
# Average Time Between Registration and Last Purchase

#Convert dates to datetime
df['Registration_Date'] = pd.to_datetime(df['Registration_Date'])
df['Last_Purchase_Date'] = pd.to_datetime(df['Last_Purchase_Date'])

#Calculate time difference then calculate the avg
df['time_between'] = (df['Last_Purchase_Date'] - df['Registration_Date']).dt.days
average_time = df['time_between'].mean()

average_time
# Out:
# 1824.3564875

# %%
# Yearly Trends in Total Purchases

# Extract year from registration date
df['Registration_Year'] = df['Registration_Date'].dt.year

# Group by 'registration_year' and calculate total purchase amount
yearly_trends = df.groupby('Registration_Year')['Purchase_Amount'].sum().reset_index()

# Total purchase amount
print(yearly_trends)

plt.plot(yearly_trends['Registration_Year'], yearly_trends['Purchase_Amount'], marker='o', color='purple', linestyle='--', linewidth=3, markersize=8)
plt.title('Yearly Trends in Total Purchases Based on Registration Date')
plt.xlabel('Year')
plt.ylabel('Total Purchase Amount')
plt.show()
# Out:
#     Registration_Year  Purchase_Amount
# 0                2010       1367506.17
# 1                2011       1357686.90
# 2                2012       1371172.75
# 3                2013       1319851.97
# 4                2014       1377130.04
# 5                2015       1350978.75
# 6                2016       1347233.12
# 7                2017       1365652.23
# 8                2018       1356479.21
# 9                2019       1345207.56
# 10               2020       1391061.21
# 11               2021       1364437.39
# 12               2022       1366539.14
# 13               2023       1377796.82
# 14               2024       1335505.50

# %%
# Check for missing values
missing_data = df.isnull().sum()
missing_percentage = (df.isnull().mean() * 100)
missing_data_summary = pd.DataFrame({'Missing Values': missing_data, 'Percentage': missing_percentage})
missing_data_summary = missing_data_summary.sort_values(by='Percentage', ascending=False)

# Print the summary of missing data
print(missing_data_summary)

# Visualize missing data with a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis', yticklabels=False)
plt.title('Heatmap of Missing Data')
plt.show()
# Out:
#                         Missing Values  Percentage
# Customer_ID                          0         0.0
# Referral_Status                      0         0.0
# Lifetime_Value                       0         0.0
# Browser_Type                         0         0.0
# Device_Type                          0         0.0
# Social_Media_Usage                   0         0.0
# Feedback_Count                       0         0.0
# Support_Tickets                      0         0.0
# Account_Age                          0         0.0
# Preferred_Brand                      0         0.0
# Return_Rate                          0         0.0
# Avg_Purchase_Frequency               0         0.0
# Promotional_Engagement               0         0.0
# Wishlist_Items                       0         0.0
# Page_Views                           0         0.0
# Search_Queries                       0         0.0
# Product_Reviews                      0         0.0
# ...

# %%
#Proportion of missing values in each column

# Calculate the proportion of missing values in each column
missing_proportion = df.isnull().mean()
print(missing_proportion)
# Out:
# Customer_ID               0.0
# Customer_Name             0.0
# Age                       0.0
# Gender                    0.0
# Email                     0.0
# Phone_Number              0.0
# Registration_Date         0.0
# Last_Purchase_Date        0.0
# Annual_Income             0.0
# Spending_Score            0.0
# Country                   0.0
# City                      0.0
# Product_Purchased         0.0
# Purchase_Amount           0.0
# Product_Rating            0.0
# Membership_Status         0.0
# Favorite_Category         0.0
# Monthly_Purchases         0.0
# Loyalty_Points            0.0
# Customer_Region           0.0
# Discount_Availability     0.0
# Delivery_Time             0.0
# Payment_Method            0.0
# Subscription_Status       0.0
# Customer_Satisfaction     0.0
# Total_Purchases           0.0
# Cart_Abandon_Rate         0.0
# Referral_Status           0.0
# Active_Days               0.0
# Lifetime_Value            0.0
# Browser_Type              0.0
# ...

# %%
# Outlier Detetion for Annual Income

Q1 = df['Annual_Income'].quantile(0.25)
Q3 = df['Annual_Income'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = df[(df['Annual_Income'] < lower_bound) | (df['Annual_Income'] > upper_bound)]

outliers
# Out:
#       Customer_ID Customer_Name  Age      Gender                  Email  \
# 11     CUST000012      rtQRYypq   28  Non-Binary     user12@example.com
# 248    CUST000249      pDcJjraM   22        Male    user249@example.com
# 337    CUST000338      dHNuEaSD   31        Male    user338@example.com
# 560    CUST000561      NqsrxHET   50        Male    user561@example.com
# 852    CUST000853      IArrFQfF   57      Female    user853@example.com
# ...           ...           ...  ...         ...                    ...
# 78287  CUST078288      DzINhqaR   69  Non-Binary  user78288@example.com
# 78296  CUST078297      MvfnNcNw   69  Non-Binary  user78297@example.com
# 79049  CUST079050      SazFxeGz   39        Male  user79050@example.com
# 79122  CUST079123      NikbDTIC   57      Female  user79123@example.com
# 79722  CUST079723      nyvEfMeU   37  Non-Binary  user79723@example.com
#
#        Phone_Number   Registration_Date  Last_Purchase_Date  Annual_Income  \
# ...

# %%
# 3. Outlier Analysis for Spending Score (using IQR)
Q1_spending = df['Spending_Score'].quantile(0.25)
Q3_spending = df['Spending_Score'].quantile(0.75)
IQR_spending = Q3_spending - Q1_spending

lower_bound_spending = Q1_spending - 1.5 * IQR_spending
upper_bound_spending = Q3_spending + 1.5 * IQR_spending
outliers_spending = df[(df['Spending_Score'] < lower_bound_spending) | (df['Spending_Score'] > upper_bound_spending)]

outliers_spending
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Customer_Name, Age, Gender, Email, Phone_Number, Registration_Date, Last_Purchase_Date, Annual_Income, Spending_Score, Country, City, Product_Purchased, Purchase_Amount, Product_Rating, Membership_Status, Favorite_Category, Monthly_Purchases, Loyalty_Points, Customer_Region, Discount_Availability, Delivery_Time, Payment_Method, Subscription_Status, Customer_Satisfaction, Total_Purchases, Cart_Abandon_Rate, Referral_Status, Active_Days, Lifetime_Value, Browser_Type, Device_Type, Social_Media_Usage, Feedback_Count, Support_Tickets, Account_Age, Preferred_Brand, Return_Rate, Avg_Purchase_Frequency, Promotional_Engagement, Wishlist_Items, Page_Views, Search_Queries, Product_Reviews, Delivery_Delays, Net_Promoter_Score, Competitor_Visits, Ad_Clicks, Avg_Time_Spent, Churn_Risk_Score, Target, time_between, Registration_Year]
# Index: []
#
# [0 rows x 53 columns]

# %%
# 4. Average Income by Gender
avg_income_by_gender = df.groupby('Gender')['Annual_Income'].mean().reset_index()
print(avg_income_by_gender)

# 5. Visualize Income Distribution by Gender (Boxplot)
sns.boxplot(x='Gender', y='Annual_Income', data=df)
plt.title('Income Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Annual Income')
plt.show()
# Out:
#        Gender  Annual_Income
# 0      Female   50500.969327
# 1        Male   50808.537665
# 2  Non-Binary   50530.822637

# %%
# Loyalty Points by Age Group

bins = [18, 25, 35, 45, 55, 65, 100]
labels = ['18-25', '26-35', '36-45', '46-55', '56-65', '65+']
df['Age_Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)
loyalty_points_by_age_group = df.groupby('Age_Group')['Loyalty_Points'].mean().reset_index()
print(loyalty_points_by_age_group)

# Visualize Loyalty Points by Age Group (Bar plot)
sns.barplot(x='Age_Group', y='Loyalty_Points', data=loyalty_points_by_age_group)
plt.title('Loyalty Points by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Average Loyalty Points')
plt.show()
# Out:
# C:\Users\850 G4\AppData\Local\Temp\ipykernel_10028\4164206477.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   loyalty_points_by_age_group = df.groupby('Age_Group')['Loyalty_Points'].mean().reset_index()
#   Age_Group  Loyalty_Points
# 0     18-25     5005.269847
# 1     26-35     5032.123338
# 2     36-45     5045.802720
# 3     46-55     5021.585473
# 4     56-65     5020.672599
# 5       65+     5047.313592

# %%
# Visualize the correlation matrix
correlation_matrix = df[numerical_columns].corr()
plt.figure(figsize=(8, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='PiYG', fmt='.2f', cbar=True, square=True, linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
# Monthly purchase trends

df['Year'] = df['Registration_Date'].dt.year
df['Month'] = df['Registration_Date'].dt.month

monthly_trends = df.groupby(['Year', 'Month'])['Purchase_Amount'].sum().reset_index()

# Combine Year and Month into a single column for easy plotting
monthly_trends['Year-Month'] = monthly_trends['Year'].astype(str) + '-' + monthly_trends['Month'].astype(str).str.zfill(2)

# Step 4: Visualize the Monthly Purchase Trends
plt.figure(figsize=(16, 8))
sns.lineplot(data=monthly_trends, x='Year-Month', y='Purchase_Amount', marker='o', color='red')
plt.title('Monthly Purchase Trends')
plt.xlabel('Month')
plt.ylabel('Total Purchase Amount')
plt.show()

# %%
# Product popularity by age group

bins = [18, 25, 35, 45, 55, 65, 100]  # Define age range boundaries
labels = ['18-25', '26-35', '36-45', '46-55', '56-65', '65+']  # Labels for each group
df['Age_Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

product_popularity = df.groupby(['Age_Group', 'Product_Purchased'])['Product_Purchased'].count().reset_index(name='Purchase_Count')

# Visualize Product Popularity by Age Group
sns.barplot(data=product_popularity, x='Age_Group', y='Purchase_Count', hue='Product_Purchased', dodge=True)
plt.title('Product Popularity by Age Group', fontsize=16)
plt.xlabel('Age Group', fontsize=12)
plt.ylabel('Number of Purchases', fontsize=12)
plt.legend(title='Product')
plt.show()
# Out:
# C:\Users\850 G4\AppData\Local\Temp\ipykernel_10028\2906510529.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   product_popularity = df.groupby(['Age_Group', 'Product_Purchased'])['Product_Purchased'].count().reset_index(name='Purchase_Count')

# %%
# Monthly Purchases Analysis

df['Registration_Date'] = pd.to_datetime(df['Registration_Date'], errors='coerce')
df['Month'] = df['Registration_Date'].dt.month_name()


monthly_trends = df.groupby(['Month'])['Purchase_Amount'].sum().reset_index()

# Visualize Monthly Purchases
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_trends, x='Month', y='Purchase_Amount', marker='o', color='b')
plt.title('Monthly Purchases Analysis')
plt.xlabel('Month')
plt.ylabel('Total Purchase Amount')
plt.show()

# %%
# Step 1: Convert 'Purchase_Date' to datetime format
df['Purchase_Date'] = pd.to_datetime(df['Purchase_Date'], errors='coerce')

# Step 2: Extract the Year and Month from the Purchase Date
df['Year'] = df['Purchase_Date'].dt.year
df['Month'] = df['Purchase_Date'].dt.month_name()  # Month names like January, February, etc.

# Step 3: Define the correct order for the months
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 
               'September', 'October', 'November', 'December']

# Convert 'Month' to a categorical type with the defined order
df['Month'] = pd.Categorical(df['Month'], categories=month_order, ordered=True)

# Step 4: Group by Year and Month and calculate total purchases or total spending
# Assuming 'Purchase_Amount' is the column for the amount spent on each purchase
monthly_trends = df.groupby(['Year', 'Month'])['Purchase_Amount'].sum().reset_index()

# Combine Year and Month for easy plotting
monthly_trends['Year-Month'] = monthly_trends['Year'].astype(str) + '-' + monthly_trends['Month']

# Step 5: Visualize Monthly Purchases with Correct Month Order
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_trends, x='Year-Month', y='Purchase_Amount', marker='o', color='b')

# Customize the plot
plt.title('Monthly Purchases Analysis', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Total Purchase Amount', fontsize=12)

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Tight layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3.0\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Purchase_Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 2
# ...
